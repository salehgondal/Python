# %%
#from selenium import webdriver
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import csv
from datetime import timedelta,date
import datetime
import urllib.request
import openpyxl

# %%
wb = openpyxl.load_workbook('PEW feeders details.xlsx')
ws = wb['Sheet1']
#print(ws.cell(row=4, column=3).hyperlink)



a= []
id=4
for i in range((ws.max_row-3)):
    #print(id)
    a.append(ws.cell(row=id, column=3).hyperlink.display)
    id+=1
#print(a)



#link_ix = 0
for link in a:
    #driver = webdriver.Chrome("C:/Users/saleh/Desktop/DSA/Python/chromedriver")
    print(link)
    #driver.get(link)
    #link_ix+=1
    #content = driver.page_source
    with urllib.request.urlopen(link) as url:
        s = url.read()
        # I'm guessing this would output the html source code ?
        #print(s)
    soup = BeautifulSoup(s)
    #soup
    #soup = BeautifulSoup(content)
    
# Get Feeder info

    t1 = []
    idx = 0
    for a in soup.findAll('table', attrs={'class':'table table-bordered table-hover table-striped'}):
        if idx == 7:
            #name=a.findAll('tr')
            for tr in a.findAll('tr'):
                #print(idx)
                for td in tr.findAll('td'):
                    t1.append(td.text.strip())
            #print(",".join(t1))
        idx += 1

#print (stack)

    f_name = t1[0]
    grid = t1[1]
    f_status = t1[2]
    loss = t1[5]

    csv_row = [t1[0], t1[1],t1[2],t1[5],'']


# get hourly info from table

    t2 = []
    idx = 0
    for a in soup.findAll('table', attrs={'class':'table table-bordered table-hover table-striped'}):
        if idx == 8:
            #name=a.findAll('tr')
            for tr in a.findAll('tr'):
            
                for td in tr.findAll('td'):
                    t2.append(td.text.strip())
            #print(",".join(stack))
        idx += 1

# Get date from website
    
    dt = 'Friday, January 24, 2020' #soup.find('p', attrs={'id':'date'}).text.strip()
    print(dt)
    f_dt = datetime.datetime.strptime(dt, '%A, %B %d, %Y').date()

# Convert list into array and apply headers
    print(1)
    t2_arr = np.array(t2)

    data = t2_arr[18:138].reshape(24,5)
    print(data)

    head=[]
    head.insert(0, ['Time', 'Schedule','Schedule', 'Actual', 'Schedule'])
    head.insert(0, [' ',f_dt-timedelta(1), f_dt, ' ',f_dt+timedelta(1)])
    head.insert(0,[t1[0], t1[1],t1[2],t1[5],''])
    
    print(3)
    out = pd.DataFrame(data=data,columns=head)#.sort_values(['Time'])
    out.head(5)
    out = out.sort_values(out.columns[0])
    print(4)
    #print(f_name.split('-')[1])

    name = f_name[f_name.index('-')+1:].lstrip()
    print(name)
    out.to_csv(name+'.csv',index=False)
    print(5)
    #driver.close()
    #driver = new ChromeDriver()

# %%
print(soup)
soup.findAll('p', attrs={'id':'date'})#.text.strip()

# %% [markdown]
# # Table data for single site

# %%
#driver = webdriver.Chrome("C:/Users/saleh/Desktop/DSA/Python/chromedriver")
link = 'http://roshanpakistan.pk/ccms/lss.php?f=083420&d=26000'
print(link)
#driver.get(link)
#link_ix+=1
    #content = driver.page_source
with urllib.request.urlopen(link) as url:
    s = url.read()
        # I'm guessing this would output the html source code ?
        #print(s)
soup = BeautifulSoup(s)
    #soup
    #soup = BeautifulSoup(content)
    
# Get Feeder info

t1 = []
idx = 0
for a in soup.findAll('table', attrs={'class':'table table-bordered table-hover table-striped'}):
    if idx == 7:
            #name=a.findAll('tr')
        print(idx)
        t1 = []
        for tr in a.findAll('tr'):
            print(idx)
            i = 0
            for td in tr.findAll('td'):
                print(f'I = #{i}')
                #if i==2:
                g = soup.find('span', {'id':'f_name'}).get_text()
                #td.getElementById("span_Id").innerText
                print(type(g))
                t1.append(td.text.strip())
                print(f'#{g} printing value')
                #i+=1
            print(",".join(t1))
    idx += 1

#print (stack)

#f_name = t1[0]
#grid = t1[1]
#f_status = t1[2]
#loss = t1[5]

#csv_row = [t1[0], t1[1],t1[2],t1[5],'']
# Out:
# http://roshanpakistan.pk/ccms/lss.php?f=083420&d=26000
# 7
# 7
# I = #0
# <class 'str'>
# # printing value
# I = #0
# <class 'str'>
# # printing value
# I = #0
# <class 'str'>
# # printing value
# I = #0
# <class 'str'>
# # printing value
# Feeder:  -,Grid:   -,Feeder Status:,
# 7
# I = #0
# <class 'str'>
# # printing value
# I = #0
# <class 'str'>
# # printing value
# I = #0
# <class 'str'>
# # printing value
# Feeder:  -,Grid:   -,Feeder Status:,,Category:,Loss %:,Net Metering Capacity:

# %%
#driver = webdriver.Chrome("C:/Users/saleh/Desktop/DSA/Python/chromedriver")
link = 'http://roshanpakistan.pk/ccms/lss.php?f=083420&d=26000'
print(link)
#driver.get(link)
#link_ix+=1
    #content = driver.page_source
with urllib.request.urlopen(link) as url:
    s = url.read()
        # I'm guessing this would output the html source code ?
    #print(s)
soup = BeautifulSoup(s)

print(soup)

soup.findAll('table', attrs={'class':'table table-bordered table-hover table-striped'})

idx=0
for a in soup.findAll('table', attrs={'class':'table table-bordered table-hover table-striped'}):
    #if idx == :
    a.text
    idx+=1
# Out:
# http://roshanpakistan.pk/ccms/lss.php?f=083420&d=26000
# <!DOCTYPE html>
# <html><head>
# <style>
# 	a:selected,	a:hover, a:active, a:focus{
# 	   outline: 0;
# 	}
#
# 	.loader{
# 	   position:absolute;
# 	   top:0;
# 	   left:0;
# 	   width:100%;
# 	   height:100%;
# 	   background:rgba(255,255,255, .8)url('images/ajax-loader.gif') no-repeat 50%
#     }
# 	tr.tr1 td{ background:#fff !important; color:#000; font-weight:bold; }
#    </style>
# <link href="index_files/css.css" rel="stylesheet" type="text/css"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="umairsalim.com" name="keywords"/>
# <title>Load Management by PITC</title>
# <link href="http://pitc.com.pk/templates/shaper_awetive/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="index_files/bootstrap.css" rel="stylesheet" type="text/css"/>
# <link href="index_files/bootstrap-responsive.css" rel="stylesheet" type="text/css"/>
# <link href="index_files/font-awesome_002.css" rel="stylesheet" type="text/css"/>
# <link href="index_files/template.css" rel="stylesheet" type="text/css"/>
# <link href="index_files/preset2.css" rel="stylesheet" type="text/css"/>
# <style type="text/css">
#
# 		#date{
# 			background: rgba(0, 0, 0, 0.1);
# 			font-size: 14px;
# 			padding: 0.5em;
# 			text-align: center;
# 		}
# 		#clock{
# 		  align-items: center;
# 		  -webkit-align-items: center;
# 		  display: flex;
# 		  display: -webkit-flex;
# 		  justify-content: space-around;
# 		  -webkit-justify-content: space-around;
# 		  /*
# 		  left: calc(50% - 300px);
# 		  position: absolute;
# 		  top: calc(50% - 65px);
# 		  */
#
# 		}
# 		.unit{
# 			background: linear-gradient(#aaa, #777);
# 			border-radius: 5px;
# 			box-shadow: 0 2px 2px #444;
# 			color: #fff;
# 			font-family: "Open Sans", sans-serif;
# 			font-size: 17px;
# 			height: 100%;
# 			line-height: 14px;
# 			margin: 0 5px;
# 			text-align: center;
# 			text-shadow: 0 2px 2px #666;
# 			width: 36px;
# 			padding: 10px;
# 		}
#         .container {
#             max-width: 1170px;
#         }
#
#
#         #sp-main-body-wrapper {
#             background: rgba(246, 180, 74, 0) !important;
#         }
#
#         #sp-main-body-wrapper {
#             background: rgba(246, 180, 74, 0) !important;
#         }
#
#         #sp-main-body-wrapper {
#             background: rgba(246, 180, 74, 0) !important;
#         }
#
#         img.sp_simple_gallery {
#             margin: 0 20px 20px 0;
#             border-radius: 2px;
#         }
#
#         #sp-smart-slider.sp-awetive-layout,
#         .sp-awetive-layout .sp-slider-item {
#             height: 400px;
#         }
#
#         @media (max-width:767px) {
#             #sp-smart-slider.sp-awetive-layout,
#             .sp-awetive-layout .sp-slider-item {
#                 height: 400px;
#             }
#         }
#
#         @media (max-width:480px) {
#             #sp-smart-slider.sp-awetive-layout,
#             .sp-awetive-layout .sp-slider-item {
#                 height: 300px;
#             }
#         }
#
# 		.modal-body {
# 			position: relative;
# 			max-height: inherit;
# 			padding: 15px;
#
# 		}
#
# 		#feeder_graph{
# 			color:#fff;
# 			height:520px;
# 			background:#ccc;
# 			margin-top:10px;
# 			margin-bottom:10px;
# 			border:0px solid #000;
# 			display:none;
# 			padding:5px;
# 		}
#
# 		td.day, td:hover.day{
# 			background-color:#49afcd !important;
# 			color:#fff !important;
# 		}
# 		td.night, td:hover.night{
# 			background-color:#444 !important;
# 			color:#fff !important;
# 		}
# 		.block_info{
# 			display: none;
# 			padding: 0.5em;
# 			width: 360px;
# 			margin-right: 30px;
# 			margin-bottom: 25px;
# 			background: lightyellow; /*#f4f4f4;*/
# 			font-size: 12px;
# 			border: 1px solid #e1e1e1;
# 			float: right;
# 		}
# 		.lbl-catg{
# 			float: left;
# 			margin-left: 5px;
# 			cursor: pointer;
# 			background-color: #000;
# 			text-align: center;
# 			color:#fff;
# 			text-shadow: 0 -1px 0 rgba(0,0,0,0.25);
# 			white-space: nowrap;
# 			vertical-align: baseline;
# 		}
# 		.trp{
# 			float:right;
# 			clear:right;
# 			margin-bottom:5px;
# 		}
#
# 		#net_metering{
# 			color:green;
# 			font-weight: bold;
# 		}
#
# 		#total_off,
# 		#live_off,
# 		#act_off,
# 		#net_metering,
# 		#category{
# 			cursor: pointer;
# 		}
# 	</style>
# <script src="jquery.js" type="text/javascript"></script>
# <script src="index_files/bootstrap.js" type="text/javascript"></script>
# <script src="index_files/jquery.maskedinput.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(document).ready(function(){
#    		var checkref='';
# 		if(checkref != ''){
#
#    			$('#btn_search').click();
#
#    		}
#     });
#
#
#
#
#
#
# 	function myfunction(){
#
# 	$('#bi_info').hide();
#
# 	if($('#ref_no').val().trim().length < 14){
# 		$('#ref_no').css("border","1px solid red");
# 		$('#ref_no').focus();
# 	}else{
#
# 		resetTripping();
# 		$('#a_tab_load').click();
# 		$('#hist').show();
# 		$('#feeder_graph').hide();
# 		$("input#ref_no").attr('disabled','disabled');
#
# 		var ref = $('#ref_no').val().trim();
# 		$('#ref_no').css("border","0px solid red");
#
#
#
#
# 		$.get('getRef.php?v='+ref, function(data) {
# 			$('#c_address').val(data);
# 			$('#a_tab_3_1').show();
# 			$('#a_tab_3_2').show();
#
# 			if(data=="Not Found"){
# 				$('#a_tab_3_1').hide();
# 				$('#a_tab_3_2').hide();
# 				$('#hist').hide();
# 				$('#bi_info').hide();
# 				$("input#ref_no").removeAttr('disabled');
# 				alert("Please enter a valid Reference No.");
# 				$("input#ref_no").focus();
# 				return false;
#
# 			}else{
# 				var _ssn = "";
# 				var sdivcode = ref.substr(2, 5);
# 				$.get('admin/get_subdivision_name.php?subdiv_code='+sdivcode, function(data) {
# 					if(data!="0"){
#
# 						var _ss = data.split('|');
# 						_ssn = _ss[1];
# 						//console.log(_ssn);
# 						$('#bi_ssn').html(_ssn);
# 					}
# 				});
#
#
#
# 				$.get('admin/get_comp_ref.php?v='+ref, function(data) {
#
# 				var d=data.split("$");
# 				$('#bi_ref').html(ref);
# 				$('#bi_name').html(d[3]+" "+d[4]);
# 				$('#bi_address').html(d[6]);
# 				$('#bi_info').show();
#
#
#
# 				$('#one').html(d[0]);
# 				$('#two').html(d[1]);
# 				$('#three').html(d[2]);
# 				$('#four').html(d[3]);
# 				$('#five').html(d[4]);
# 				$('#six').html(d[5]);
# 				$('#seven').html(d[6]);
# 				$('#eight').html(d[7]);
# 				$('#nine').html(d[8]);
# 				$('#ten').html(d[9]);
# 				$('#eleven').html(d[10]);
# 				$('#twelve').html(d[11]);
# 				$('#thirteen').html(d[12]);
#
# 				var cls = "info";
#
# 				var status = d[13];
#
# 				if(status=='ACTIVE'){
# 					cls = "success";
# 				}else{
# 					if(status==''){
# 						status='NOT FOUND';
# 					}else{
# 						cls = "danger";
# 					}
# 				}
#
# 				var str = "<span class='label label-"+cls+"'>"+status+"</span>";
# 				$('#current_status').html(str);
# 				$('#11').html(d[14]);
# 				$('#22').html(d[15]);
# 				$('#33').html(d[16]);
# 				$('#44').html(d[17]);
# 				$('#55').html(d[18]);
# 				$('#66').html(d[19]);
# 				$("#txt").val(d[19]);
#
# 				if(d[0]=='0')
# 				{
# 				document.getElementById("sch_info").children[2].style.display = 'none';
# 				}else{
#
# 					mybutton(d[19], d[0], 1);
#
# 					document.getElementById("sch_info").children[2].style.display = 'block';
# 				}
# 				//$('#669').html(d[19]);
# 				$('#77').html(d[20]);
# 				$('#111').html(d[21]);
# 				$('#222').html(d[22]);
# 				$('#333').html(d[23]);
# 				$('#444').html(d[24]);
# 				$('#555').html(d[25]);
# 				$('#666').html(d[26]);
# 				$('#777').html(d[27]);
# 				$('#888').html(d[28]);
# 				$('#999').html(d[29]);
# 				$('#100').html(d[30]);
#
#
# 			});
#
# 			$.get('admin/get_bill_ref.php?v='+ref, function(data) {
#
# 				$('#1111').html('');
# 				$('#2222').html('');
# 				$('#3333').html('');
# 				$('#4444').html('');
# 				$('#month1').html('');
# 				$('#bill1').html('');
# 				$('#month2').html('');
# 				$('#bill2').html('');
# 				$('#month3').html('');
# 				$('#bill3').html('');
# 				$('#month4').html('');
# 				$('#bill4').html('');
# 				$('#month5').html('');
# 				$('#bill5').html('');
# 				$('#month6').html('');
# 				$('#bill6').html('');
# 				$('#month7').html('');
# 				$('#bill7').html('');
# 				$('#month8').html('');
# 				$('#bill8').html('');
# 				$('#month9').html('');
# 				$('#bill9').html('');
# 				$('#month10').html('');
# 				$('#bill10').html('');
# 				$('#month11').html('');
# 				$('#bill11').html('');
# 				$('#month12').html('');
# 				$('#bill12').html('');
#
# 				if(data == "BILL_DATA_NOT_FOUND"){
# 					$('#1111').html('Bill Data Not Found');
# 				}else{
# 					var d=data.split("$");
# 					var fs = new Date(d[0]);
# 					 y = fs.getFullYear();
# 					 m = fs.getMonth()+1;
#
# 					var M='00';
#
# 					 if(m<10){
# 						M='0'+m;
# 					 }else{
# 						M=m;
# 					 }
#
# 					$('#1111').html(y+'-'+M);
#
# 					$('#2222').html(d[1]);
# 					$('#3333').html(d[2]);
# 					$('#4444').html(d[3]);
# 					$('#month1').html(d[4]);
# 					$('#bill1').html(d[5]);
# 					$('#month2').html(d[6]);
# 					$('#bill2').html(d[7]);
# 					$('#month3').html(d[8]);
# 					$('#bill3').html(d[9]);
# 					$('#month4').html(d[10]);
# 					$('#bill4').html(d[11]);
# 					$('#month5').html(d[12]);
# 					$('#bill5').html(d[13]);
# 					$('#month6').html(d[14]);
# 					$('#bill6').html(d[15]);
# 					$('#month7').html(d[16]);
# 					$('#bill7').html(d[17]);
# 					$('#month8').html(d[18]);
# 					$('#bill8').html(d[19]);
# 					$('#month9').html(d[20]);
# 					$('#bill9').html(d[21]);
# 					$('#month10').html(d[22]);
# 					$('#bill10').html(d[23]);
# 					$('#month11').html(d[24]);
# 					$('#bill11').html(d[25]);
# 					$('#month12').html(d[26]);
# 					$('#bill12').html(d[27]);
#
# 				}
# 			});
#
#
#
# 			}
# 		});
#
#
#
# 		//$('#loader').css('display', 'none');
#
#
#
# 	}
# }
#
# 	function duplicate_bill()
# 	{
#
# 	if( $('#ref_no').val().trim().length < 14)
# 	{
# 		$('#ref_no').css("border","1px solid red");
# 		$('#ref_no').focus();
# 	}
#
# 	else
# 	{
# 		var ref = $('#ref_no').val().trim();
# 		var disco_code = ref.substr(2, 2)+'000';
# 		var batch=ref.substr(0,2);
#
#  		if(disco_code==11000)
# 		{
# 			window.open('http://ccms.pitc.com.pk/ccms/duplicate_bill_lesco.php?ref='+ref);
#
#  		}else if(disco_code==12000)
# 		{
# 			if(batch < 24) {
# 			window.open("http://210.56.23.106:888/gepcobill/general/"+ref);
# 			}else{ window.open("http://210.56.23.106:888/gepcobill/industrial/"+ref);}
#
#  		}else if(disco_code==13000)
# 		{
# 				if(batch < 24) {
# 			 window.open("http://210.56.23.106:888/fescobill/general/"+ref);
# 				}else{ window.open("http://210.56.23.106:888/fescobill/industrial/"+ref);}
#
# 		}else if(disco_code==14000)
#  		{
# 				if(batch < 24) {
#
#  		 	window.open("http://210.56.23.106:888/iescobill/general/"+ref);
# 				}else{ window.open("http://210.56.23.106:888/iescobill/industrial/"+ref);}
#
# 		}else if(disco_code==15000)
# 		{ 	 if(batch < 24) {
# 			 window.open("http://210.56.23.106:888/mepcobill/general/"+ref);
# 			}else{ window.open("http://210.56.23.106:888/mepcobill/industrial/"+ref); }
#
#
# 		}else if(disco_code==26000)
# 		{		if(batch < 24) {
# 			 window.open("http://210.56.23.106:888/mepcobill/general/"+ref);
# 					}else{window.open("http://210.56.23.106:888/mepcobill/industrial/"+ref); }
#
# 		}else if(disco_code==37000)
# 		{
# 			if(batch < 24) {
# 			window.open("http://210.56.23.106:888/hescobill/general/"+ref);
# 			}else{ window.open("http://210.56.23.106:888/hescobill/industrial/"+ref); }
#
# 		}else if(disco_code==38000)
# 		{
# 			if(batch < 24) {
#  			window.open("http://210.56.23.106:888/sepcobill/general/"+ref);
# 			}else{ window.open("http://210.56.23.106:888/sepcobill/industrial/"+ref); }
# 		}else
# 		{
# 			if(batch < 24) {
#  			window.open("http://210.56.23.106:888/qescobill/general/"+ref);
# 			}else{window.open("http://210.56.23.106:888/qescobill/industrial/"+ref); }
# 		}
#
#
# 	}
#
# }
#
# function resetTripping(){
# 	$('#bi_ssn').html('');
# 	$('#bi_ref').html('');
# 	$('#bi_name').html('');
# 	$('#bi_address').html('');
#
# 	$('#glaxy_status').html('');
# 	$('#ptw_status').html('');
# 	$('#category').html('');
# 	$('#loss_per').html('');
# 	$('#net_metering').html('');
# 	$('#total_off').html('');
# 	$('#act_off').html('');
# 	$('#live_off').html('');
#   	$('#f_code').html('');
# 	$('#f_name').html('');
# 	$('#grid_code').html('');
# 	$('#grid_name').html('');
#
# 	for(var i=1; i<=24; i++){
# 			$('#schp1_'+i).html('');
# 			$('#live_'+i).html('');
# 			$('#sch_'+i).html('');
# 	}
#
# }
#
#
#
# function resetHistory(){
#
# 	$('#schp1_1').html(' ');
# 	$('#schp1_2').html(' ');
# 	$('#schp1_3').html(' ');
# 	$('#schp1_4').html(' ');
#
# 	$('#schp1_5').html(' ');
# 	$('#schp1_6').html(' ');
# 	$('#schp1_7').html(' ');
# 	$('#schp1_8').html(' ');
#
# 	$('#schp1_9').html(' ');
# 	$('#schp1_10').html(' ');
# 	$('#schp1_11').html(' ');
# 	$('#schp1_12').html(' ');
#
# 	$('#schp1_13').html(' ');
# 	$('#schp1_14').html(' ');
# 	$('#schp1_15').html(' ');
# 	$('#schp1_16').html(' ');
#
# 	$('#schp1_17').html(' ');
# 	$('#schp1_18').html(' ');
# 	$('#schp1_19').html(' ');
# 	$('#schp1_20').html(' ');
#
# 	$('#schp1_21').html(' ');
# 	$('#schp1_22').html(' ');
# 	$('#schp1_23').html(' ');
# 	$('#schp1_24').html(' ');
# }
#
# function resetLive(){
# 	$('#live_1').html(' ');
# 	$('#live_2').html(' ');
# 	$('#live_3').html(' ');
# 	$('#live_4').html(' ');
# 	$('#live_5').html(' ');
# 	$('#live_6').html(' ');
# 	$('#live_7').html(' ');
# 	$('#live_8').html(' ');
# 	$('#live_9').html(' ');
# 	$('#live_10').html(' ');
# 	$('#live_11').html(' ');
# 	$('#live_12').html(' ');
# 	$('#live_13').html(' ');
# 	$('#live_14').html(' ');
# 	$('#live_15').html(' ');
# 	$('#live_16').html(' ');
# 	$('#live_17').html(' ');
# 	$('#live_18').html(' ');
# 	$('#live_19').html(' ');
# 	$('#live_20').html(' ');
# 	$('#live_21').html(' ');
# 	$('#live_22').html(' ');
# 	$('#live_23').html(' ');
# 	$('#live_24').html(' ');
# }
#
#
# function convertMintoHr(minutes) {
#   var h = Math.floor(minutes / 60);
#   var m = minutes % 60;
#   h = h < 10 ? '0' + h : h;
#   m = m < 10 ? '0' + m : m;
#   return h + 'h ' + m + 'm';
# }
#
# function mybutton(feeder_code, ref_no, source){
#
#
# for(var n=0; n<=24; n++){
# 	$('#msch_'+n).html('<span></span>');
# }
#
# var company_code ="";
# if(source==1){
# 	company_code = ref_no.substr(2, 2)+'000';
#
# }else{
# 	company_code = ref_no;
# }
#
#
# $('#glaxy_status').html('');
#
# //resetLive();
# //resetHistory();
#
# $.get('search_feeder_intervals.php?disco_code='+company_code, function(data) {
# 	//var json_obj = $.parseJSON(data);//parse JSON
# 	var json_obj = data;//parse JSON
# 	if(json_obj['INTERVALS'][0].DISCO_FOUND=="TRUE"){
# 		//alert(json_obj['INTERVALS'][0].DISCO_FOUND);
# 		inv_1 = json_obj['INTERVALS'][1].inv_1;
# 		inv_2 = json_obj['INTERVALS'][1].inv_2;
# 		inv_3 = json_obj['INTERVALS'][1].inv_3;
# 		inv_4 = json_obj['INTERVALS'][1].inv_4;
# 		inv_5 = json_obj['INTERVALS'][1].inv_5;
# 		inv_6 = json_obj['INTERVALS'][1].inv_6;
# 		inv_7 = json_obj['INTERVALS'][1].inv_7;
# 		inv_8 = json_obj['INTERVALS'][1].inv_8;
# 		inv_9 = json_obj['INTERVALS'][1].inv_9;
# 		inv_10 = json_obj['INTERVALS'][1].inv_10;
# 		inv_11 = json_obj['INTERVALS'][1].inv_11;
# 		inv_12 = json_obj['INTERVALS'][1].inv_12;
#
# 		inv_13 = json_obj['INTERVALS'][1].inv_13;
# 		inv_14 = json_obj['INTERVALS'][1].inv_14;
# 		inv_15 = json_obj['INTERVALS'][1].inv_15;
# 		inv_16 = json_obj['INTERVALS'][1].inv_16;
# 		inv_17 = json_obj['INTERVALS'][1].inv_17;
# 		inv_18 = json_obj['INTERVALS'][1].inv_18;
# 		inv_19 = json_obj['INTERVALS'][1].inv_19;
# 		inv_20 = json_obj['INTERVALS'][1].inv_20;
# 		inv_21 = json_obj['INTERVALS'][1].inv_21;
# 		inv_22 = json_obj['INTERVALS'][1].inv_22;
# 		inv_23 = json_obj['INTERVALS'][1].inv_23;
# 		inv_24 = json_obj['INTERVALS'][1].inv_24;
#
# 		$('#inv_1').html(inv_1);
# 		$('#inv_2').html(inv_2);
# 		$('#inv_3').html(inv_3);
# 		$('#inv_4').html(inv_4);
# 		$('#inv_5').html(inv_5);
# 		$('#inv_6').html(inv_6);
# 		$('#inv_7').html(inv_7);
# 		$('#inv_8').html(inv_8);
# 		$('#inv_9').html(inv_9);
# 		$('#inv_10').html(inv_10);
# 		$('#inv_11').html(inv_11);
# 		$('#inv_12').html(inv_12);
#
# 		$('#inv_13').html(inv_13);
# 		$('#inv_14').html(inv_14);
# 		$('#inv_15').html(inv_15);
# 		$('#inv_16').html(inv_16);
# 		$('#inv_17').html(inv_17);
# 		$('#inv_18').html(inv_18);
# 		$('#inv_19').html(inv_19);
# 		$('#inv_20').html(inv_20);
# 		$('#inv_21').html(inv_21);
# 		$('#inv_22').html(inv_22);
# 		$('#inv_23').html(inv_23);
# 		$('#inv_24').html(inv_24);
#
# 	}
#
# 	//for (var i in json_obj)
#     //{
# 	//	output+="<li>" + json_obj[i].DISCO_FOUND + ",  " + json_obj[i].ID + "</li>";
# 	//}
#
# });
#
# 			var d = new Date();
# 			var n = d.getHours();
# 			var i = 0;
# 			var j = 0;
#
#
# 			$.get('glaxy_api.php?feeder_code='+feeder_code+'&disco_code='+company_code, function(data) {
#
# 				var json_obj = $.parseJSON(data);//parse JSON
# 				$('#glaxy_status').html(json_obj.status);
#
#
# 				$.get('admin/duration2.php?v='+feeder_code, function(data) {
#
# 				if(data.trim()!='Not Found'){
# 					var dd=data.split("#");
# 					var ddd=dd[0].split("$");
# 					var tot_off = 0;
# 					var tot_off_maintenance = 0;
# 					var category=dd[1];
# 					var feeder_loss=dd[2].trim();
# 					$.each(ddd, function (index, value) {
#
# 					  value = value.trim();
#
# 					  if(value == 'OFF'){
# 							tot_off = tot_off + 1;
# 							ddd[index] = '<span class="label label-danger">OFF</span>';
#
# 					  }
# 					  if(value == 'ON'){
# 							//ddd[index] = '<span class="label label-success">ON</span>';
# 					  }
#
#
#
# 					});
#
#
# 					$('#f_code').html( ddd[0]);
# 					$('#f_name').html( ddd[1]);
# 					$('#grid_code').html( ddd[2]);
# 					$('#grid_name').html( ddd[3]);
# 					$('#category').html(category);
#
# 					if(feeder_loss.trim()!=''){
# 						feeder_loss = parseFloat(feeder_loss);
# 						feeder_loss = feeder_loss.toFixed(2);
# 						if(feeder_loss < 0){
# 							feeder_loss = 0;
# 						}
# 					}else{
# 						feeder_loss = '';
# 					}
#
# 					$('#loss_per').html(feeder_loss);
#
# 					var y=0;
# 					for(var x=1; x<=24; x++){
# 						y = eval(x+3);
# 						$('#sch_'+x).html(ddd[y]);
# 						if($('#sch_'+x+' span').html()=='OFF'){
# 							$('#msch_'+x).html('<span class="label label-danger">OFF</span>');
# 						}else{
# 							$('#msch_'+x).html('<span>ON</span>');
# 						}
# 					}
#
#
# 					if(json_obj.maintenance_tomorrow != null){
# 						$.each( json_obj.maintenance_tomorrow, function( index, value ){
# 							j = index + 1;
# 							//alert(value);
# 							if(eval(value) != 0){
# 								//tot_off = tot_off + 1;
# 								$('#sch_'+j).html('<span class="label label-danger">OFF</span>');
# 							}
# 						});
# 					}
#
#
#
# 					if(json_obj.maintenance != null){
# 						$.each( json_obj.maintenance, function( index, value ){
# 							i = index + 1;
# 							if(eval(value) != 0){
# 								tot_off_maintenance = tot_off_maintenance + 1;
# 								$('#msch_'+i).html('<span class="label label-danger">OFF</span>');
# 							}else{
# 								//$('#msch_'+i).html('<span>ON</span>');
# 								//$('#msch_'+i).html('');
# 							}
# 						});
# 					}
#
# 					if(tot_off_maintenance > 0 ){
# 						tot_off = tot_off+tot_off_maintenance;
# 					}
#
#
# 					$('#total_off').html(tot_off + " Hour(s)");
#
# 				  }
#
# 				});
#
#
# 				$('#net_metering').html('');
# 				//SHOW NET METERING
# 				$.get('search_net_metering_api.php?feeder_code='+feeder_code, function(nmdata) {
# 					var json_obj1 = nmdata;//parse JSON
# 					var str = "";
# 					if(json_obj1['net_metering'][0].status=="TRUE"){
# 						var available_capacity = json_obj1['net_metering'][0].available_capacity;
# 						str = "sub division="+json_obj1['net_metering'][0].subdiv_name + "     " +
# 							  "connections="+json_obj1['net_metering'][0].no_of_conn + "     " +
# 							  "applications="+json_obj1['net_metering'][0].no_of_app;
# 						$('#net_metering').html(available_capacity + ' MW');
# 						//$('#nm_data').show();
# 					}else{
# 						$('#net_metering').html("<span style='color:red;'>Not Available</span>");
# 						str = "";
# 						//$('#nm_data').hide();
# 					}
# 					$('#net_metering').attr('title', str);
# 				});
#
#
#
#
# 				if(json_obj.status=='OFF'){
#
# 					//SHOW PTW DETAILS
# 					$.get('search_feeder_ptw.php?feeder_code='+feeder_code, function(data) {
# 						var json_obj = data;//parse JSON
# 						if(json_obj['FEEDER'][0].PTW_FOUND=="TRUE"){
# 							var type = json_obj['FEEDER'][1].type;
# 							$('#ptw_status').html(type + ' is in progress for ' + json_obj['FEEDER'][1].duration);
# 							var str = json_obj['FEEDER'][1].date + "  (" + json_obj['FEEDER'][1].from + "-" + json_obj['FEEDER'][1].to+")";
# 							$('#ptw_status').attr('title', str);
# 						}
#
# 						if(json_obj['FEEDER'][0].PTW_FOUND=="FALSE"){
# 							//$('#ptw_status').html('No PTW');
# 							$('#ptw_status').html('');
# 							$('#ptw_status').attr('title', '');
# 						}
# 					});
# 				}
#
#
#
#
# 			var live_off = 0;
# 			i=0;
# 			if(json_obj.today != null){
# 				$.each( json_obj.today, function( index, value ){
# 					i = index + 1;
# 					live_off += value;
# 					if( index < n){
# 						if(eval(value) != 0){
# 							$('#live_'+i).html('<span class="label  label-warning" style="background-color:#E25856;">'+value+'</span>');
# 						}else{
# 							//$('#live_'+i).html('<span class="label label-success">ON</span>');
# 							$('#live_'+i).html('ON');
# 						}
# 					}else{
# 						$('#live_'+i).html('-');
# 					}
# 				});
# 			}
# 			$('#live_off').html(convertMintoHr(live_off));
#
# 			var act_off = 0;
# 			i=0;
# 			if(json_obj.yesterday != null){
# 				$.each( json_obj.yesterday, function( index, value ){
# 					i = index + 1;
# 					act_off += value;
# 					if(eval(value) != 0){
# 						$('#schp1_'+i).html('<span class="label  label-warning">'+value+'</span>');
# 					}else{
# 						//$('#schp1_'+i).html('<span class="label label-success">ON</span>');
# 						$('#schp1_'+i).html('ON');
# 					}
# 				});
# 			}
# 			$('#act_off').html(convertMintoHr(act_off));
#
# 			$('#hist').hide();
#
#
#
#
# 		});
#
#
#
#
#
# $("#igraph").attr("src", "admin/draw_glaxy_graph_lss.php?feeder_code="+feeder_code);
#
# $('#feeder_graph').show();
#
# $("input#ref_no").removeAttr('disabled');
#
# }
# </script>
# <link href="css/default.css" rel="stylesheet" type="text/css"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-111648452-1"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
#
# 	gtag('config', 'UA-111648452-1');
# 	</script>
# </head>
# <body class="bg clearfix">
# <div class="body-innerwrapper">
# <header id="sp-header-wrapper">
# <div class="container">
# <div class="row-fluid" id="header">
# <div class="span6" id="sp-logo">
# <div class="logo-wrapper"><a href="http://pitc.com.pk/">
# <img alt="" class="image-logo" src="index_files/logo.jpg"/></a></div>
# </div>
# <div class="span3 offset3" id="sp-top-info">
# <div class="module">
# <div class="mod-wrapper clearfix">
# <div class="mod-content clearfix">
# <div class="mod-inner clearfix">
# <div class="custom">
# <p>
# <img alt="moelogo" src="index_files/moelogo.png" style="margin-top: 0px; float: right;"/></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="gap"></div>
# </div>
# </div>
# </div>
# </header>
# <section class="reg-form" id="">
# <div class="container">
# <div class="row-fluid">
# <form action="" class="register" enctype="multipart/form-data" id="frmRegister" method="post">
# <div class="infobox">
# <!-- nav start -->
# <style>
# #clockcss, #header{
# 	display:block;
# }
#
# @media(max-width:768px) and (max-width:979px) {
# #clockcss{
# 	display:none;
# }
# #header{ display:none; }
# }
# </style>
# <section class="" id="sp-menu-wrapper">
# <div class="row-fluid" id="menu">
# <div class="span12" id="sp-menu">
# <div class="visible-desktop" id="sp-main-menu">
# <ul class="sp-menu level-0">
# <li class="menu-item first">
# <a class="menu-item active first" href="http://roshanpakistan.pk/ccms/lss.php"><span class="menu"><span class="menu-title">Home</span></span></a>
# </li>
# <li class="menu-item">
# <a class="menu-item" href="http://roshanpakistan.pk/lmr/"><span class="menu"><span class="menu-title">LMR</span></span></a></li>
# <li class="menu-item">
# <a class="menu-item" href="http://roshanpakistan.pk/pp/"><span class="menu"><span class="menu-title">Daily Power Position</span></span></a></li>
# <li class="menu-item">
# <a class="menu-item" href="http://roshanpakistan.pk/net_metering/"><span class="menu"><span class="menu-title">Search Net-Metering</span></span></a></li>
# <li class="menu-item">
# <a class="menu-item last" href="http://roshanpakistan.pk/ccms/search.php"><span class="menu"><span class="menu-title">Search Feeder</span></span></a></li>
# <li class="menu-item">
# <a class="menu-item last" href="http://roshanpakistan.pk/ccms/mobile_no.php"><span class="menu"><span class="menu-title">Verify Customer</span></span></a></li>
# </ul>
# </div>
# <a class="hidden-desktop btn btn-inverse sp-main-menu-toggler" data-target=".nav-collapse" data-toggle="collapse" href="#" style="margin: 0;margin-top: -20px;margin-left: -30px;">
# <i class="icon-align-justify"></i>
# </a>
# </div>
# <div class="hidden-desktop sp-mobile-menu nav-collapse collapse">
# <ul class="">
# <li class="menu-item active first">
# <a class="menu-item active first" href="http://roshanpakistan.pk/ccms/lss.php"><span class="menu"><span class="menu-title">Home</span></span></a>
# </li>
# <li class="menu-item">
# <a class="menu-item" href="http://roshanpakistan.pk/lmr/"><span class="menu"><span class="menu-title">Load Management Report</span></span></a></li>
# <li class="menu-item">
# <a class="menu-item" href="http://roshanpakistan.pk/pp/"><span class="menu"><span class="menu-title">Daily Power Position</span></span></a></li>
# <li class="menu-item">
# <a class="menu-item" href="http://roshanpakistan.pk/net_metering/"><span class="menu"><span class="menu-title">Search Net-Metering</span></span></a></li>
# <li class="menu-item">
# <a class="menu-item last" href="http://roshanpakistan.pk/ccms/search.php"><span class="menu"><span class="menu-title">Search Feeder</span></span></a></li>
# <li class="menu-item">
# <a class="menu-item last" href="http://roshanpakistan.pk/ccms/mobile_no.php"><span class="menu"><span class="menu-title">Verify Customer</span></span></a>
# </li>
# </ul>
# </div>
# </div>
# </section>
# <!-- nav end -->
# <h3 class="complaint">Load Management Portal</h3>
# <div class="table-responsive" style="overflow:auto;">
# <table class="table" style="margin-bottom:0;">
# <tr>
# <td valign="top">
# <fieldset>
# <div style="clear:both; overflow:hidden; padding-bottom:10px; height: 140px;">
# <div>
# <div style="float:left;">
# <label>
# <b>*Enter 14 digit Reference No.</b>
# </label>
# <input id="ref_no" maxlength="14" name="ref_no" required="required" style="width:300px; padding: 3px; float:left; margin-right:10px; " type="text" value=""/>
# <input id="page" name="page" type="hidden" value="1"/>
# <a class="btn btn-danger" href="javascript:void(0);" id="btn_search" onclick="myfunction();" style="float:left;">Search</a><br/>
# <small id="hist" style="clear:left; float:left; color:#000; font-weight:bold; padding-top: 10px; display:none;">Loading data, please wait...</small>
# </div>
# <div id="clockcss" style="float:right;">
# <p id="date"></p>
# <div id="clock">
# <p class="unit" id="hours"></p>
# <p class="unit" id="minutes"></p>
# <p class="unit" id="seconds"></p>
# <p class="unit" id="ampm"></p>
# </div>
# </div>
# <div class="block_info" id="bi_info">
# <b>Subdivision: <span id="bi_ssn" style="color:red; font-size:16px;"></span></b><br/>
# 											Reference No: <b><span id="bi_ref"></span></b><br/>
# 											Name: <span id="bi_name"></span><br/>
# 											Address: <span id="bi_address"></span>
# </div>
# </div>
# </div>
# <div class="form-group" style="font-size:12px; position:relative;">
# <div class="loader" id="loader" style="display:none;"></div>
# <div class="col-md-12">
# <!-- Tabs-->
# <div class="tabbable tabbable-custom">
# <!-- Only required for left/right tabs -->
# <ul class="nav nav-tabs tabs-left" id="sch_info" style="margin-bottom:0px;">
# <!--onClick="mybutton(document.getElementById('txt').value,document.getElementById('ref_no').value)"-->
# <li class="active" style="display:block;">
# <a data-toggle="tab" href="#tab_3_3" id="a_tab_load"><span id="click">Load Management Info</span></a>
# </li>
# <li><a data-toggle="tab" href="#tab_3_1" id="a_tab_3_1" style="display:none;">Consumer Info</a></li>
# <li><a data-toggle="tab" href="#tab_3_2" id="a_tab_3_2" style="display:none;">Billing Info</a></li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane" id="tab_3_1">
# <!--=== Table  ===-->
# <div class="tabbable tabbable-custom">
# <ul class="nav nav-tabs" style="display:none;">
# <li class="active"><a data-toggle="tab" href="#tab_1_1">Basic</a></li>
# <li style="display:none"><a data-toggle="tab" href="#tab_1_2">Meter Info</a></li>
# <li><a data-toggle="tab" href="#tab_1_3">W/E Info</a></li>
# <li><a data-toggle="tab" href="#tab_1_5">Feeder Info</a></li>
# <li><a data-toggle="tab" href="#tab_1_4">FBR Info</a></li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane active" id="tab_1_1">
# <div class="table-responsive">
# <table class="table table-bordered table-hover table-striped">
# <tbody>
# <tr>
# <th width="150">Status</th>
# <td><span id="current_status"></span></td>
# </tr>
# <tr>
# <th> Ref No </th>
# <td><span id="one"></span>-<span id="two"></span></td>
# </tr>
# <tr>
# <th> Name </th>
# <td><span id="four"></span> <span id="five"></span></td>
# </tr>
# <tr>
# <th> CNIC</th>
# <td><span id="six"></span></td>
# </tr>
# <tr>
# <th> Address</th>
# <td><span id="seven"></span> <span id="eight"></span></td>
# </tr>
# <tr>
# <th> Conn. Date </th>
# <td><span id="three"></span></td>
# </tr>
# <tr>
# <th> Tariff</th>
# <td><span id="nine"></span></td>
# </tr>
# <tr>
# <th>Sanction Load</th>
# <td><span id="ten"></span></td>
# </tr>
# <tr>
# <th> No of AC</th>
# <td><span id="eleven"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="tab-pane" id="tab_1_2">
# <p></p><div class="col-lg-12">
# <div class="table-responsive">
# <table class="table table-bordered table-hover table-striped">
# <tbody>
# <tr>
# <th> Meter Type </th>
# <td><span id="55"></span>-Phase</td>
# </tr>
# <tr>
# <th> CONN. Date </th>
# <td><span id="333"></span></td>
# </tr>
# <tr>
# <th>MCO Date</th>
# <td><span id="777"></span></td>
# </tr>
# <tr>
# <th> DEF Date </th>
# <td><span id="555"></span></td>
# </tr>
# <tr>
# <th> DEF Times</th>
# <td><span id="999"></span></td>
# </tr>
# <tr>
# <th> DCN Date</th>
# <td><span id="222"></span></td>
# </tr>
# <tr>
# <th> DCN Issue No. </th>
# <td><span id="11"></span></td>
# </tr>
# <tr>
# <th> DCN Issue Date</th>
# <td><span id="22"></span></td>
# </tr>
# <tr>
# <th> DCN Exe Date </th>
# <td><span id="33"></span></td>
# </tr>
# <tr>
# <th> DCN Age </th>
# <td><span id="44"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="tab-pane" id="tab_1_3">
# <p></p><div class="col-lg-12">
# <div class="table-responsive">
# <table class="table table-bordered table-hover table-striped">
# <tbody>
# <tr>
# <th>Dept Code</th>
# <td><span id="111"></span></td>
# </tr>
# <tr>
# <th>BPS Code</th>
# <td><span id="444"></span></td>
# </tr>
# <tr>
# <th>Emp Name</th>
# <td><span id="666"></span></td>
# </tr>
# <tr>
# <th>EPF No</th>
# <td><span id="888"></span></td>
# </tr>
# <tr>
# <th>Balance Units</th>
# <td><span id="100"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="tab-pane" id="tab_1_4">
# <div class="col-lg-12">
# <div class="table-responsive">
# <table class="table table-bordered table-hover table-striped">
# <tbody>
# <tr>
# <th> NTN No</th>
# <td><span id="twelve"></span></td>
# </tr>
# <tr>
# <th> Sales Tax Return No </th>
# <td><span id="thirteen"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="tab-pane" id="tab_1_5">
# <p></p><div class="col-lg-12">
# <div class="table-responsive">
# <table class="table table-bordered table-hover table-striped">
# <tbody>
# <tr>
# <th> Feeder Code</th>
# <td><a href="#" onclick="$('#click').click()"><span id="66"></span></a></td>
# </tr>
# <tr>
# <th> Transformer Code</th>
# <td><span id="77"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--=== Table  ===-->
# </div>
# <div class="tab-pane" id="tab_3_2">
# <div class="table-responsive">
# <table class="table table-bordered table-hover table-striped">
# <tbody>
# <tr>
# <th width="150">Billing Month</th>
# <td>
# <span id="1111"></span>
# <a class="btn btn-xs btn-danger" href="javascript:void(0);" id="btn_search" onclick="duplicate_bill()" style="float:right;"><i class="icon-print"></i> Print Duplicate Bill</a>
# </td>
# </tr>
# <tr style="display:none;">
# <th>Current Amount Due</th>
# <td><span id="2222"></span></td>
# </tr>
# <tr>
# <th>Payable within Due Date </th>
# <td><span id="3333"></span></td>
# </tr>
# <tr>
# <th>Meter Status </th>
# <td><span id="4444"></span></td>
# </tr>
# </tbody>
# </table>
# <table class="table table-bordered table-hover table-striped">
# <tr>
# <th> Month</th>
# <th> Payment</th>
# <th> Month</th>
# <th> Payment</th>
# </tr>
# <tr>
# <td><span id="month1"></span></td>
# <td><span id="bill1"></span></td>
# <td><span id="month7"></span> </td>
# <td> <span id="bill7"> </span></td>
# </tr>
# <tr>
# <td><span id="month2"></span></td>
# <td><span id="bill2"> </span></td>
# <td> <span id="month8"> </span></td>
# <td> <span id="bill8"> </span></td>
# </tr>
# <tr>
# <td><span id="month3"></span></td>
# <td><span id="bill3"> </span></td>
# <td><span id="month9"></span></td>
# <td> <span id="bill9"> </span></td>
# </tr>
# <tr>
# <td><span id="month4"></span></td>
# <td><span id="bill4"> </span></td>
# <td><span id="month10"></span></td>
# <td> <span id="bill10"> </span></td>
# </tr>
# <tr>
# <td><span id="month5"></span></td>
# <td><span id="bill5"> </span></td>
# <td> <span id="month11"></span> </td>
# <td> <span id="bill11"> </span></td>
# </tr>
# <tr>
# <td><span id="month6"></span></td>
# <td><span id="bill6"> </span></td>
# <td><span id="month12"></span></td>
# <td> <span id="bill12"> </span></td>
# </tr>
# </table>
# </div>
# </div>
# <div class="tab-pane active" id="tab_3_3">
# <!--=== Table  ===-->
# <div class="col-lg-12">
# <div class="table-responsive">
# <table class="table table-bordered table-hover table-striped" style="margin-bottom:0; white-space: nowrap;">
# <tbody>
# <tr>
# <td><b>Feeder:</b> <span id="f_code"></span> - <span id="f_name"></span>
# <input id="txt" name="feedrcdtxt" type="hidden" value=""/></td>
# <td><b>Grid:</b> <span id="grid_code"> </span> - <span id="grid_name"> </span></td>
# <td>
# <span style="float:left; padding-right:5px; font-weight:bold;">Feeder Status: </span>
# <span class="label label-info" id="glaxy_status" style="float:left; margin-right:5px; cursor:pointer;" title="Feeder Status"></span>
# <span class="label label-success" id="ptw_status" style="float:left; margin-left:5px; cursor:pointer;"></span>
# </td>
# <td rowspan="2" style="width:100px;">
# <span class="label label-danger trp" id="total_off" title="Planned"></span>
# <span class="label label-info trp" id="live_off" style="background-color:#E25856;" title="Actual"></span>
# <span class="label label-warning trp" id="act_off" title="History"></span>
# </td>
# </tr>
# <tr>
# <td><span style="float:left; padding-right:5px; font-weight:bold;">Category:</span><span class="label lbl-catg" id="category" title="I=Upto 10	II=10 to 20	III=20 to 30	IV=30 to 40	V=40 to 60	VI=60 to 80	VII=80.1 &amp; Above"></span></td>
# <td><span style="float:left; padding-right:5px; font-weight:bold;">Loss %:</span><span class="label lbl-catg" id="loss_per"></span></td>
# <td><div id="nm_data"><span style="float:left; padding-right:5px; font-weight:bold;">Net Metering Capacity:</span><span id="net_metering"></span></div></td>
# </tr>
# </tbody>
# </table>
# <table class="table table-bordered table-hover table-striped">
# <tbody>
# <tr class="tr1">
# <td></td>
# <td>Tomorrow</td>
# <td colspan="2" style="text-align:center;">Today</td>
# <td>Yesterday</td>
# <td></td>
# <td>Tomorrow</td>
# <td colspan="2" style="text-align:center;">Today</td>
# <td>Yesterday</td>
# </tr>
# <tr class="tr1">
# <td>AM</td>
# <td>Schedule</td>
# <td>Schedule</td>
# <td>Actual</td>
# <td>Schedule</td>
# <td>PM</td>
# <td>Schedule</td>
# <td>Schedule</td>
# <td>Actual</td>
# <td>Schedule</td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_1">00:00</span></td>
# <td><span id="sch_1"> </span></td>
# <td><span id="msch_1"> </span></td>
# <td><span id="live_1"></span></td>
# <td><span id="schp1_1"> </span> </td>
# <td class="night"> <span id="inv_13">12:00</span></td>
# <td> <span id="sch_13"> </span></td>
# <td><span id="msch_13"> </span></td>
# <td><span id="live_13"></span></td>
# <td><span id="schp1_13"> </span></td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_2">01:00</span></td>
# <td><span id="sch_2"> </span></td>
# <td><span id="msch_2"> </span></td>
# <td><span id="live_2"></span></td>
# <td><span id="schp1_2"> </span></td>
# <td class="night"> <span id="inv_14">01:00</span></td>
# <td><span id="sch_14"> </span></td>
# <td><span id="msch_14"> </span></td>
# <td><span id="live_14"></span></td>
# <td><span id="schp1_14"> </span> </td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_3">02:00</span></td>
# <td><span id="sch_3"> </span></td>
# <td><span id="msch_3"> </span></td>
# <td><span id="live_3"></span></td>
# <td><span id="schp1_3"> </span></td>
# <td class="night"> <span id="inv_15">02:00</span></td>
# <td><span id="sch_15"> </span> </td>
# <td><span id="msch_15"> </span></td>
# <td><span id="live_15"></span></td>
# <td><span id="schp1_15"> </span></td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_4">03:00</span></td>
# <td><span id="sch_4"> </span></td>
# <td><span id="msch_4"> </span></td>
# <td><span id="live_4"></span></td>
# <td><span id="schp1_4"> </span></td>
# <td class="night"> <span id="inv_16">03:00</span></td>
# <td><span id="sch_16"> </span> </td>
# <td><span id="msch_16"> </span></td>
# <td><span id="live_16"></span></td>
# <td><span id="schp1_16"> </span></td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_5">04:00</span></td>
# <td><span id="sch_5"> </span> </td>
# <td><span id="msch_5"> </span></td>
# <td><span id="live_5"></span></td>
# <td><span id="schp1_5"> </span></td>
# <td class="night"> <span id="inv_17">04:00</span></td>
# <td><span id="sch_17"> </span> </td>
# <td><span id="msch_17"> </span></td>
# <td><span id="live_17"></span></td>
# <td><span id="schp1_17"> </span> </td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_6">05:00</span></td>
# <td><span id="sch_6"> </span></td>
# <td><span id="msch_6"> </span></td>
# <td><span id="live_6"></span></td>
# <td><span id="schp1_6"> </span> </td>
# <td class="night"> <span id="inv_18">05:00</span></td>
# <td><span id="sch_18"> </span> </td>
# <td><span id="msch_18"> </span></td>
# <td><span id="live_18"></span></td>
# <td><span id="schp1_18"> </span> </td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_7">06:00</span></td>
# <td><span id="sch_7"> </span></td>
# <td><span id="msch_7"> </span></td>
# <td><span id="live_7"></span></td>
# <td><span id="schp1_7"> </span></td>
# <td class="night"> <span id="inv_19">06:00</span></td>
# <td> <span id="sch_19"> </span></td>
# <td><span id="msch_19"> </span></td>
# <td><span id="live_19"></span></td>
# <td><span id="schp1_19"> </span></td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_8">07:00</span></td>
# <td> <span id="sch_8"> </span></td>
# <td><span id="msch_8"> </span></td>
# <td><span id="live_8"></span></td>
# <td><span id="schp1_8"> </span></td>
# <td class="night"> <span id="inv_20">07:00</span></td>
# <td> <span id="sch_20"> </span></td>
# <td><span id="msch_20"> </span></td>
# <td><span id="live_20"></span></td>
# <td><span id="schp1_20"> </span></td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_9">08:00</span></td>
# <td><span id="sch_9"> </span> </td>
# <td><span id="msch_9"> </span></td>
# <td><span id="live_9"></span></td>
# <td><span id="schp1_9"> </span> </td>
# <td class="night"> <span id="inv_21">08:00<span></span></span></td>
# <td><span id="sch_21"> </span> </td>
# <td><span id="msch_21"> </span></td>
# <td><span id="live_21"></span></td>
# <td><span id="schp1_21"> </span> </td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_10">09:00</span></td>
# <td> <span id="sch_10"> </span></td>
# <td><span id="msch_10"> </span></td>
# <td><span id="live_10"></span></td>
# <td><span id="schp1_10"> </span></td>
# <td class="night"> <span id="inv_22">09:00</span></td>
# <td><span id="sch_22"> </span></td>
# <td><span id="msch_22"> </span></td>
# <td><span id="live_22"></span></td>
# <td><span id="schp1_22"> </span> </td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_11">10:00</span></td>
# <td><span id="sch_11"> </span></td>
# <td><span id="msch_11"> </span></td>
# <td><span id="live_11"></span></td>
# <td><span id="schp1_11"> </span> </td>
# <td class="night"> <span id="inv_23">10:00</span></td>
# <td><span id="sch_23"> </span> </td>
# <td><span id="msch_23"> </span></td>
# <td><span id="live_23"></span></td>
# <td><span id="schp1_23"> </span></td>
# </tr>
# <tr>
# <td class="day"> <span id="inv_12">11:00</span></td>
# <td><span id="sch_12"> </span> </td>
# <td><span id="msch_12"> </span></td>
# <td><span id="live_12"></span></td>
# <td><span id="schp1_12"></span> </td>
# <td class="night"> <span id="inv_24">11:00</span></td>
# <td><span id="sch_24"> </span> </td>
# <td><span id="msch_24"> </span></td>
# <td><span id="live_24"></span></td>
# <td><span id="schp1_24"></span></td>
# </tr>
# </tbody>
# </table>
# <div id="feeder_graph">
# <iframe frameborder="0" height="100%" id="igraph" src="admin/draw_glaxy_graph_lss.php" width="100%"></iframe>
# <!--<iframe id="igraph" src="admin/draw_glaxy_graph_lss_inverse.php"  frameborder="0" width="100%" height="100%"></iframe> -->
# </div>
# </div>
# </div>
# <!--=== Table  ===-->
# </div>
# </div>
# </div>
# <!--END TABS-->
# </div>
# </div>
# </fieldset>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </form>
# </div>
# </div>
# </section>
# <footer id="sp-footer-wrapper">
# <div class="container">
# <div class="row-fluid" id="footer">
# <div class="span11" id="sp-footer1"><span class="copyright">Copyright ©  2020 Power Information Technology Company - PITC,  All Rights Reserved.<br/><small>( for technical support send an email to <a href="mailto: umair.salim@pitc.com.pk" title="send email">umair.salim@pitc.com.pk</a> )</small></span></div>
# <div class="span1" id="sp-footer2"><a class="sp-totop" href="#" rel="nofollow" title="Goto Top"><small>Goto Top </small><i class="icon-angle-up"></i></a></div>
# </div>
# </div>
# </footer>
# </div>
# <script>
# var $dOut = $('#date'),
#     $hOut = $('#hours'),
#     $mOut = $('#minutes'),
#     $sOut = $('#seconds'),
#     $ampmOut = $('#ampm');
# var months = [
#   'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'
# ];
#
# var days = [
#   'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'
# ];
#
# function update(){
#   var date = new Date();
#
#   var ampm = date.getHours() < 12
#              ? 'AM'
#              : 'PM';
#
#   var hours = date.getHours() == 0
#               ? 12
#               : date.getHours() > 12
#                 ? date.getHours() - 12
#                 : date.getHours();
#
#   var minutes = date.getMinutes() < 10
#                 ? '0' + date.getMinutes()
#                 : date.getMinutes();
#
#   var seconds = date.getSeconds() < 10
#                 ? '0' + date.getSeconds()
#                 : date.getSeconds();
#
#   var dayOfWeek = days[date.getDay()];
#   var month = months[date.getMonth()];
#   var day = date.getDate();
#   var year = date.getFullYear();
#
#   var dateString = dayOfWeek + ', ' + month + ' ' + day + ', ' + year;
#
#   $dOut.text(dateString);
#   $hOut.text(hours);
#   $mOut.text(minutes);
#   $sOut.text(seconds);
#   $ampmOut.text(ampm);
# }
#
# update();
# window.setInterval(update, 1000);
# 	mybutton('083420','26000', 0);
#
# </script>
# </body>
# </html>

# %%
# get hourly info from table

t2 = []
idx = 0
for a in soup.findAll('table', attrs={'class':'table table-bordered table-hover table-striped'}):
    if idx == 8:
            #name=a.findAll('tr')
        for tr in a.findAll('tr'):
            
            for td in tr.findAll('td'):
                t2.append(td.text.strip())
            #print(",".join(stack))
    idx += 1

# Get date from website
    
dt = 'Friday, January 24, 2020' #soup.find('p', attrs={'id':'date'}).text.strip()
print(dt)
f_dt = datetime.datetime.strptime(dt, '%A, %B %d, %Y').date()

# %%
# Convert list into array and apply headers
print(1)
t2_arr = np.array(t2)

data = t2_arr[18:138].reshape(24,5)
print(data)

head=[]
head.insert(0, ['Time', 'Schedule','Schedule', 'Actual', 'Schedule'])
head.insert(0, [' ',f_dt-timedelta(1), f_dt, ' ',f_dt+timedelta(1)])
head.insert(0,[t1[0], t1[1],t1[2],t1[5],''])

print(3)
out = pd.DataFrame(data=data,columns=head)#.sort_values(['Time'])
out.head(5)
out = out.sort_values(out.columns[0])
print(4)
#print(f_name.split('-')[1])

name = f_name[f_name.index('-')+1:].lstrip()
print(name)
out.to_csv(name+'.csv',index=False)
print(5)
#driver.close()
#driver = new ChromeDriver()
